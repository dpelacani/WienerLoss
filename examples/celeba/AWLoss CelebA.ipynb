# %% [markdown]
# **18 Apr, Touchpoint**
#
# 1. Kick-off on April 12th with Debbie, in which some doubts were clarified and the **concept and code for development were introduced**.
#
# 2. The **frequency analysis was implemented**, so that it is possible to reproduce the analysis between spatial and temporal domains, according to the [FFL paper](https://arxiv.org/pdf/2012.12821.pdf).
#
# 3. It was **not yet possible to reproduce the results for the [CelebA](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html)** using either CPU and GPU. My main hypothesis is related to the data, since I didn't have access to the one used for training and had to download it.
#
# 4. Given the issue with CelebA, I chose to do at first a **POC with FashionMNIST**. Using the same CelebA Autoencoder, I trained the model using 3 different metrics: MSE, FFL and AWL. For 5 epochs, **preliminary results indicate that AWL was able to better reconstruct images**.
#
# **Next steps**
#
# 1. **Identify the problem with CelebA** so that it is possible to train the model on this dataset. In the future, reproduce with CelebAHQ
#
# 2. **Access to a more robust machine**, so that it is possible to accelerate the training.
#
# 3. Isolate the FFL metric for training, without the MSE.
#
# 4. Try on Variational AE

# %% [markdown]
# # Setup

# %%
# Mount drive
from google.colab import drive
drive.mount("/content/gdrive")

# Set up the files
# %cp -av /content/gdrive/MyDrive/utils /content/utils

# Set up the dataset
# !mkdir data
# !mkdir data/CelebA
# !unzip /content/gdrive/MyDrive/CelebA/img_align_celeba.zip -d /content/data/CelebA/
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/data/CelebA/img_align_celeba/197600.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197601.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197602.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197603.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197604.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197605.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197606.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197607.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197608.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197609.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197610.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197611.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197612.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197613.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197614.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197615.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197616.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197617.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197618.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197619.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197620.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197621.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197622.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197623.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197624.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197625.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197626.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197627.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197628.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197629.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197630.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197631.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197632.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197633.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197634.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197635.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197636.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197637.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197638.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197639.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197640.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197641.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197642.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197643.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197644.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197645.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197646.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197647.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197648.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197649.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197650.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197651.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197652.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197653.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197654.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197655.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197656.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197657.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197658.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197659.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197660.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197661.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197662.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197663.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197664.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197665.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197666.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197667.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197668.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197669.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197670.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197671.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197672.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197673.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197674.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197675.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197676.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197677.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197678.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197679.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197680.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197681.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197682.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197683.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197684.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197685.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197686.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197687.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197688.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197689.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197690.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197691.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197692.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197693.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197694.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197695.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197696.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197697.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197698.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197699.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197700.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197701.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197702.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197703.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197704.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197705.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197706.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197707.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197708.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197709.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197710.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197711.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197712.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197713.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197714.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197715.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197716.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197717.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197718.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197719.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197720.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197721.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197722.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197723.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197724.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197725.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197726.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197727.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197728.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197729.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197730.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197731.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197732.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197733.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197734.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197735.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197736.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197737.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197738.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197739.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197740.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197741.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197742.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197743.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197744.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197745.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197746.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197747.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197748.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197749.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197750.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197751.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197752.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197753.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197754.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197755.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197756.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197757.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197758.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197759.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197760.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197761.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197762.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197763.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197764.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197765.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197766.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197767.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197768.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197769.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197770.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197771.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197772.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197773.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197774.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197775.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197776.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197777.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197778.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197779.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197780.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197781.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197782.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197783.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197784.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197785.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197786.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197787.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197788.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197789.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197790.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197791.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197792.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197793.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197794.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197795.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197796.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197797.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197798.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197799.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197800.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197801.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197802.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197803.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197804.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197805.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197806.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197807.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197808.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197809.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197810.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197811.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197812.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197813.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197814.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197815.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197816.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197817.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197818.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197819.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197820.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197821.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197822.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197823.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197824.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197825.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197826.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197827.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197828.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197829.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197830.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197831.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197832.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197833.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197834.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197835.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197836.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197837.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197838.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197839.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197840.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197841.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197842.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197843.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197844.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197845.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197846.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197847.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197848.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197849.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197850.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197851.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197852.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197853.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197854.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197855.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197856.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197857.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197858.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197859.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197860.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197861.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197862.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197863.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197864.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197865.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197866.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197867.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197868.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197869.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197870.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197871.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197872.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197873.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197874.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197875.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197876.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197877.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197878.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197879.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197880.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197881.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197882.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197883.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197884.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197885.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197886.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197887.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197888.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197889.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197890.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197891.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197892.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197893.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197894.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197895.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197896.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197897.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197898.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197899.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197900.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197901.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197902.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197903.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197904.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197905.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197906.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197907.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197908.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197909.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197910.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197911.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197912.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197913.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197914.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197915.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197916.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197917.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197918.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197919.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197920.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197921.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197922.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197923.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197924.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197925.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197926.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197927.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197928.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197929.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197930.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197931.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197932.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197933.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197934.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197935.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197936.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197937.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197938.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197939.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197940.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197941.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197942.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197943.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197944.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197945.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197946.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197947.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197948.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197949.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197950.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197951.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197952.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197953.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197954.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197955.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197956.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197957.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197958.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197959.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197960.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197961.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197962.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197963.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197964.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197965.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197966.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197967.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197968.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197969.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197970.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197971.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197972.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197973.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197974.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197975.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197976.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197977.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197978.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197979.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197980.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197981.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197982.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197983.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197984.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197985.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197986.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197987.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197988.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197989.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197990.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197991.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197992.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197993.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197994.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197995.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197996.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197997.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197998.jpg
#  extracting: /content/data/CelebA/img_align_celeba/197999.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198000.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198001.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198002.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198003.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198004.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198005.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198006.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198007.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198008.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198009.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198010.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198011.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198012.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198013.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198014.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198015.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198016.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198017.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198018.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198019.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198020.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198021.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198022.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198023.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198024.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198025.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198026.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198027.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198028.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198029.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198030.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198031.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198032.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198033.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198034.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198035.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198036.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198037.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198038.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198039.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198040.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198041.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198042.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198043.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198044.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198045.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198046.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198047.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198048.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198049.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198050.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198051.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198052.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198053.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198054.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198055.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198056.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198057.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198058.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198059.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198060.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198061.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198062.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198063.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198064.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198065.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198066.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198067.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198068.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198069.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198070.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198071.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198072.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198073.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198074.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198075.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198076.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198077.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198078.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198079.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198080.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198081.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198082.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198083.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198084.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198085.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198086.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198087.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198088.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198089.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198090.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198091.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198092.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198093.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198094.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198095.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198096.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198097.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198098.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198099.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198100.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198101.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198102.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198103.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198104.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198105.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198106.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198107.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198108.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198109.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198110.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198111.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198112.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198113.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198114.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198115.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198116.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198117.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198118.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198119.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198120.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198121.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198122.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198123.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198124.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198125.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198126.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198127.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198128.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198129.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198130.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198131.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198132.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198133.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198134.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198135.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198136.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198137.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198138.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198139.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198140.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198141.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198142.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198143.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198144.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198145.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198146.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198147.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198148.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198149.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198150.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198151.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198152.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198153.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198154.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198155.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198156.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198157.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198158.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198159.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198160.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198161.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198162.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198163.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198164.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198165.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198166.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198167.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198168.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198169.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198170.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198171.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198172.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198173.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198174.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198175.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198176.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198177.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198178.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198179.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198180.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198181.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198182.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198183.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198184.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198185.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198186.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198187.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198188.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198189.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198190.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198191.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198192.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198193.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198194.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198195.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198196.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198197.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198198.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198199.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198200.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198201.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198202.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198203.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198204.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198205.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198206.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198207.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198208.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198209.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198210.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198211.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198212.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198213.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198214.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198215.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198216.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198217.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198218.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198219.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198220.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198221.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198222.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198223.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198224.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198225.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198226.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198227.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198228.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198229.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198230.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198231.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198232.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198233.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198234.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198235.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198236.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198237.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198238.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198239.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198240.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198241.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198242.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198243.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198244.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198245.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198246.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198247.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198248.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198249.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198250.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198251.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198252.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198253.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198254.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198255.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198256.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198257.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198258.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198259.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198260.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198261.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198262.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198263.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198264.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198265.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198266.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198267.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198268.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198269.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198270.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198271.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198272.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198273.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198274.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198275.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198276.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198277.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198278.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198279.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198280.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198281.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198282.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198283.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198284.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198285.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198286.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198287.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198288.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198289.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198290.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198291.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198292.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198293.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198294.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198295.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198296.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198297.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198298.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198299.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198300.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198301.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198302.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198303.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198304.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198305.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198306.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198307.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198308.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198309.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198310.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198311.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198312.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198313.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198314.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198315.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198316.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198317.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198318.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198319.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198320.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198321.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198322.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198323.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198324.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198325.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198326.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198327.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198328.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198329.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198330.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198331.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198332.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198333.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198334.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198335.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198336.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198337.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198338.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198339.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198340.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198341.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198342.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198343.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198344.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198345.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198346.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198347.jpg
#  extracting: /content/data/CelebA/img_align_celeba/198348.jpg
# ...
#  extracting: /content/data/CelebA/img_align_celeba/202350.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202351.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202352.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202353.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202354.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202355.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202356.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202357.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202358.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202359.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202360.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202361.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202362.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202363.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202364.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202365.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202366.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202367.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202368.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202369.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202370.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202371.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202372.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202373.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202374.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202375.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202376.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202377.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202378.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202379.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202380.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202381.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202382.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202383.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202384.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202385.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202386.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202387.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202388.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202389.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202390.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202391.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202392.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202393.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202394.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202395.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202396.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202397.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202398.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202399.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202400.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202401.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202402.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202403.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202404.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202405.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202406.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202407.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202408.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202409.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202410.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202411.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202412.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202413.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202414.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202415.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202416.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202417.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202418.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202419.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202420.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202421.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202422.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202423.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202424.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202425.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202426.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202427.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202428.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202429.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202430.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202431.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202432.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202433.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202434.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202435.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202436.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202437.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202438.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202439.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202440.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202441.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202442.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202443.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202444.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202445.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202446.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202447.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202448.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202449.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202450.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202451.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202452.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202453.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202454.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202455.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202456.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202457.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202458.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202459.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202460.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202461.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202462.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202463.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202464.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202465.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202466.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202467.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202468.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202469.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202470.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202471.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202472.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202473.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202474.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202475.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202476.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202477.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202478.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202479.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202480.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202481.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202482.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202483.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202484.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202485.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202486.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202487.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202488.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202489.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202490.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202491.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202492.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202493.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202494.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202495.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202496.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202497.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202498.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202499.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202500.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202501.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202502.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202503.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202504.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202505.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202506.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202507.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202508.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202509.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202510.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202511.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202512.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202513.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202514.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202515.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202516.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202517.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202518.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202519.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202520.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202521.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202522.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202523.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202524.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202525.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202526.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202527.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202528.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202529.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202530.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202531.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202532.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202533.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202534.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202535.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202536.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202537.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202538.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202539.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202540.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202541.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202542.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202543.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202544.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202545.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202546.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202547.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202548.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202549.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202550.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202551.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202552.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202553.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202554.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202555.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202556.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202557.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202558.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202559.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202560.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202561.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202562.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202563.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202564.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202565.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202566.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202567.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202568.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202569.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202570.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202571.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202572.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202573.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202574.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202575.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202576.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202577.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202578.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202579.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202580.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202581.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202582.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202583.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202584.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202585.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202586.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202587.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202588.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202589.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202590.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202591.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202592.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202593.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202594.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202595.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202596.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202597.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202598.jpg
#  extracting: /content/data/CelebA/img_align_celeba/202599.jpg

# %%
# Set up the environment
# !pip install -r utils/requirements.txt --quiet
# !pip install -r utils/requirements-optional.txt --quiet
# !pip install livelossplot --quiet
# !pip install torch-summary>=1.4.5 --quiet
# !pip install progressbar2 --quiet
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 15.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 kB 4.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 867.9/867.9 kB 22.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 87.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 6.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.9/721.9 kB 57.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.3/47.3 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 86.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.2/66.2 kB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 597.6/597.6 kB 54.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 8.2 MB/s eta 0:00:00
#   Building wheel for memory-profiler (setup.py) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.5.3, but you have pandas 1.4.2 which is incompatible.

# %% [markdown]
# # Imports

# %%
import copy
import os
import random

from utils.awloss import AWLoss
from utils.freqloss import FocalFrequencyLoss as FFLoss

# %load_ext autoreload
import numpy as np
import torch
import torch.nn as nn

from livelossplot import PlotLosses
from progressbar import ProgressBar
from tqdm import tqdm
from torchvision.transforms import Compose, ToTensor, CenterCrop, Resize, Grayscale
from torchvision.datasets import ImageFolder
from torchvision.utils import make_grid
from torch.utils.data import DataLoader, Subset
from torchsummary import summary

# %autoreload 2
import sys
sys.path.append('../') 
from utils.networks import *
from utils.utils import *
from utils.landscape import *
from utils.datasets import *
from utils.train_utils import *

import json
import pathlib
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

# %% [markdown]
# # Hyperparameters

# %%
# Note: The utils functions below were taken from the from notebooks provided in the lectures.
def set_seed(seed):
    """
    Use this to set ALL the random seeds to a fixed value and take out any randomness from cuda kernels
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.benchmark = True  ##uses the inbuilt cudnn auto-tuner to find the fastest convolution algorithms. -
    torch.backends.cudnn.enabled   = True

    return True

def set_device(device="cpu", idx=0):
    if device != "cpu":
        if torch.cuda.device_count() > idx and torch.cuda.is_available():
            print("Cuda installed! Running on GPU {} {}!".format(idx, torch.cuda.get_device_name(idx)))
            device="cuda:{}".format(idx)
        elif torch.cuda.device_count() > 0 and torch.cuda.is_available():
            print("Cuda installed but only {} GPU(s) available! Running on GPU 0 {}!".format(torch.cuda.device_count(), torch.cuda.get_device_name()))
            device="cuda:0"
        else:
            device="cpu"
            print("No GPU available! Running on CPU")
    return device

set_seed(42)
device = set_device("cuda")
torch.cuda.empty_cache()
torch.autograd.set_detect_anomaly(True)
# Out:
# Cuda installed! Running on GPU 0 Tesla T4!

# %%
# Set training static parameters and hyperparameters
nepochs = 5
latent_size = 128                            
learning_rate = 1e-3
batch_size = 512                                        
valid_ratio = 0.2
logf = int(nepochs//5) + 1
sampling = .2

# %% [markdown]
# # Dataset

# %%
# Datasets and Dataloaders
img_dim = 64
dataset = ImageFolder(root="./data/CelebA/",
                      transform=Compose([
                          Resize(img_dim),
                          CenterCrop(img_dim),
                          ToTensor()
                       ]))

# Train an Validation split
idxs = np.arange(0, len(dataset), 1)
np.random.shuffle(idxs)
train_idxs, valid_idxs = (idxs[:-int(len(dataset) * valid_ratio)],
                         idxs[-int(len(dataset) * valid_ratio):])

# train_idxs, valid_idxs = (idxs[:int(len(dataset) * (1 - valid_ratio) * 0.05)],
#                          idxs[-int(len(dataset) * valid_ratio * 0.05):])

trainds, validds = (Subset(dataset, train_idxs), 
                    Subset(dataset, valid_idxs))
print(f"Total: {len(trainds) + len(validds)}")
print("    Training images: {} \n    Validation Images: {}".format(len(trainds), len(validds)))

# Dataloaders
train_loader = DataLoader(trainds, batch_size=batch_size, 
                          shuffle=True, 
                        #   num_workers=4
                          num_workers=2)
valid_loader = DataLoader(validds, batch_size=batch_size, 
                          shuffle=False, 
                        #   num_workers=4
                          num_workers=2)

# Visualise batch
sample_batch = next(iter(train_loader))[0][:32]
plt.figure(figsize=(8,8))
plt.imshow(np.transpose(make_grid(sample_batch, pad_value=0, padding=3).numpy(), (1,2,0)))
plt.xticks([]); plt.yticks([])
plt.show()

print("\n")
print(sample_batch.shape, sample_batch.min().item(), sample_batch.max().item())
# Out:
# Total: 202599
#     Training images: 162080
#     Validation Images: 40519
# torch.Size([32, 3, 64, 64]) 0.0 1.0

# %% [markdown]
# # Model (Utils)

# %%
class Convolution(nn.Module):
    """Base class for convolution operations"""
    def __init__(self, input, output,
                 kernel=3, padding=1, stride=1,
                 activation="Mish"):
        """
        Parameters
        ----------
        input : int
            Input channels

        output : int
            Output channels

        kernel : int or tuple
            Kernel size

        padding : int
            Padding size

        stride : int or tuple
            Stride size

        activation : str
            Activation function. Available is "LeakyReLU", "ReLU",
            "Tanh", "Mish" and "Sigmoid"
        """
        super(Convolution, self).__init__()

        # Define the activation layer
        if activation == "LeakyReLU":
            self.activation = nn.LeakyReLU(0.2)
        elif activation == "ReLU":
            self.activation = nn.ReLU()
        elif activation == "Tanh":
            self.activation = nn.Tanh()
        elif activation == "Mish":
             self.activation = nn.Mish()   
        elif activation == "Sigmoid":
            self.activation = nn.Sigmoid()
        else:
            raise ValueError("Activation function not implemented.")

        # Define the convolutional layer
        self.convolution = nn.Sequential(
            nn.Conv2d(input, output,
                      kernel_size=kernel,
                      padding=padding,
                      stride=stride),
            nn.BatchNorm2d(output),
            self.activation,
        )

    def forward(self, x):
        """Apply the forward operation.

        Parameters
        ---------
        x : torch.tensor
            image
        """
        return self.convolution(x)


class Encoder(nn.Module):
    """Convolutional Autoencoder"""
    def __init__(self, 
                 channels, features,
                 latent_dimension, 
                 img_dim):
        """
        Parameters
        ----------
        channels : int
            Number of channels of the images

        features : int
            Number of input features in the discriminator
            
        latent_dimension : int
            Number of dimensions of the latent space 

        img_dim : 
            Number of pixels in one dimension of the image 
        """
        super(Encoder, self).__init__()

        # Define the encoder 
        self.encoder = nn.Sequential(
            # output: bs,   features, img_dim, img_dim
            Convolution(input=channels, output=features),

            # output: bs,   features, img_dim/2, img_dim/2
            torch.nn.MaxPool2d(kernel_size=(2, 2)),

            # output: bs, 2*features, img_dim/2, img_dim/2
            Convolution(input=features, output=features * 2),

            # output: bs, 2*features, img_dim/4, img_dim/4
            torch.nn.MaxPool2d(kernel_size=(2, 2)),

            # output: bs, 4*features, img_dim/4, img_dim/4
            Convolution(input=features * 2, output=features * 4), 

            # output: bs, 4*features*(img_dim/4)**2
            nn.Flatten(start_dim=1), 

            # output: latent_dimension
            nn.Linear(int(4 * features * img_dim / 4 * img_dim / 4),
                      latent_dimension),
        )
        
        # Initialize the weights following N(0, 0.02)
        self.init_parameters()

    def init_parameters(self, mean=0, std=0.02):
        """Force initialization of parameters according
           to Radford et. al (2015). Adapted from RNN lecture 
           notebook
           
        Parameters
        ----------
        mean : float
            Mean for parameters initialization

        std : float
            Standard deviation forparameters initialization
        """
        for w in self.parameters():
            w.data.normal_(mean, std)

    def forward(self, x):
        """Apply the forward operation on the Encoder.

        Parameters
        ---------
        x : torch.tensor
            FashionMNIST image
        """
        # Perform the encoding
        z = self.encoder(x)
        return z


class Decoder(nn.Module):
    """Convolutional Decoder"""
    def __init__(self, 
                 channels, features,
                 latent_dimension,
                 img_dim):
        """
        Parameters
        ----------
        channels : int
            Number of channels of the images
        
        features : int
            Number of input features in the discriminator
        
        latent_dimension : int
            Size of the input tensor in the generator

        img_dim : 
            Number of pixels in one dimension of the image 
        """
        super(Decoder, self).__init__()

        # Define the decoder 
        self.decoder = nn.Sequential(
            # output: bs, 4*features*(img_dim/4)**2
            nn.Linear(latent_dimension, int(4 * features * img_dim / 4 * img_dim / 4)),

            # output: bs, 4*features, img_dim/4, img_dim/4
            nn.Unflatten(dim=1, unflattened_size=(4 * features, int(img_dim / 4), int(img_dim / 4))),

            # output: bs, 2*features, img_dim/4, img_dim/4
            Convolution(input=(4 * features), output=features * 2),

            # output: bs, 2*features, img_dim/2, img_dim/2
            torch.nn.Upsample(scale_factor=2),

            # output: bs,   features, img_dim/2, img_dim/2
            Convolution(input=features * 2, output=features * 1),

            # output: bs,   features,   img_dim,  img_dim
            torch.nn.Upsample(scale_factor=2),

            # output: bs,   features,   img_dim,  img_dim
            torch.nn.Conv2d(features, channels, 3, 1, 1),

            torch.nn.Sigmoid()
        )

        # Initialize the weights following N(0, 0.002)
        self.init_parameters()

    def init_parameters(self, mean=0, std=0.02):
        """Force initialization of parameters according
           to Radford et. al (2015). Adapted from RNN lecture 
           notebook
           
        Parameters
        ----------
        mean : float
            Mean for parameters initialization

        std : float
            Standard deviation forparameters initialization
        """
        for w in self.parameters():
            w.data.normal_(mean, std)

    def forward(self, z):
        """Apply the forward operation on the Decoder.

        Parameters
        ---------
        x : torch.tensor
            FashionMNIST image
        """
        # Decode
        y = self.decoder(z)
        return y

class CAE(nn.Module):
    """Convolutional Autoencoder"""
    def __init__(self, device, channels, features,
                 latent_dimension, img_dim):
        """
        Parameters
        ----------
        device : str
            Device for the calculations

        channels : int
            Number of channels of the images
        
        features : int
            Number of input features in the discriminator
            
        latent_dimension : int
            Size of the input tensor in the generator

        img_dim : 
            Number of pixels in one dimension of the image 
        
        """
        super(CAE, self).__init__()
        self.device = device
        self.encoder = Encoder(channels=channels, features=features,
                               latent_dimension=latent_dimension,
                               img_dim=img_dim)
        self.decoder = Decoder(channels=channels, features=features,
                               latent_dimension=latent_dimension,
                               img_dim=img_dim)
        self.distribution = torch.distributions.Normal(0, 1)

    def forward(self, x):
        '''Apply the forward operation on the CCVAE.

        Parameters
        ---------
        x : torch.tensor
            FashionMNIST image
        
        '''
        z = self.encoder(x)                  # Run the image through the Encoder
        y = self.decoder(z)                  # Return the output of the decoder (the predicted image)
        return y


def model_instance(device, channels, 
                   features, latent_dimension,
                   img_dim):
    """Create an instance of the model.
    
    Parameters
    ----------
    device : str
        Device for the calculations

    channels : int
        Number of channels of the images
    
    features : int
        Number of input features in the discriminator
        
    latent_dimension : int
        Size of the input tensor in the generator

    img_dim : 
        Number of pixels in one dimension of the image 
    
    """
    # Instantiate the model
    model = CAE(device=device, channels=channels,
                features=features,
                latent_dimension=latent_dimension,
                img_dim=img_dim).to(device).to(device)
    
    # Parallelise the model
    # model = nn.DataParallel(model, device_ids=[0, 1])
    model = nn.DataParallel(model)

    return model

# %% [markdown]
# # Model

# %%
# Hyperparameters
channels = 3                                        # Number of channels in the images
features = 16                                       # Number of input features in the encoder
latent_dimension = 128                              # Number of dimensions of the latent space  

# Model Summary
_ = summary(model=model_instance(device=device, channels=channels,
                                 features=features,
                                 latent_dimension=latent_dimension,
                                 img_dim=img_dim),
            input_data=sample_batch[0].shape,
            verbose=1, depth=4, 
            col_names=["input_size", 
                       "output_size", 
                       "num_params"])
# Out:
# ========================================================================================================================
# Layer (type:depth-idx)                        Input Shape               Output Shape              Param #
# ========================================================================================================================
# ├─CAE: 1-1                                    [-1, 3, 64, 64]           [-1, 3, 64, 64]           --
# |    └─Encoder: 2-1                           [-1, 3, 64, 64]           [-1, 128]                 --
# |    |    └─Sequential: 3-1                   [-1, 3, 64, 64]           [-1, 128]                 --
# |    |    |    └─Convolution: 4-1             [-1, 3, 64, 64]           [-1, 16, 64, 64]          480
# |    |    |    └─MaxPool2d: 4-2               [-1, 16, 64, 64]          [-1, 16, 32, 32]          --
# |    |    |    └─Convolution: 4-3             [-1, 16, 32, 32]          [-1, 32, 32, 32]          4,704
# |    |    |    └─MaxPool2d: 4-4               [-1, 32, 32, 32]          [-1, 32, 16, 16]          --
# |    |    |    └─Convolution: 4-5             [-1, 32, 16, 16]          [-1, 64, 16, 16]          18,624
# |    |    |    └─Flatten: 4-6                 [-1, 64, 16, 16]          [-1, 16384]               --
# |    |    |    └─Linear: 4-7                  [-1, 16384]               [-1, 128]                 2,097,280
# |    └─Decoder: 2-2                           [-1, 128]                 [-1, 3, 64, 64]           --
# |    |    └─Sequential: 3-2                   [-1, 128]                 [-1, 3, 64, 64]           --
# |    |    |    └─Linear: 4-8                  [-1, 128]                 [-1, 16384]               2,113,536
# |    |    |    └─Unflatten: 4-9               [-1, 16384]               [-1, 64, 16, 16]          --
# |    |    |    └─Convolution: 4-10            [-1, 64, 16, 16]          [-1, 32, 16, 16]          18,528
# |    |    |    └─Upsample: 4-11               [-1, 32, 16, 16]          [-1, 32, 32, 32]          --
# |    |    |    └─Convolution: 4-12            [-1, 32, 32, 32]          [-1, 16, 32, 32]          4,656
# |    |    |    └─Upsample: 4-13               [-1, 16, 32, 32]          [-1, 16, 64, 64]          --
# |    |    |    └─Conv2d: 4-14                 [-1, 16, 64, 64]          [-1, 3, 64, 64]           435
# |    |    |    └─Sigmoid: 4-15                [-1, 3, 64, 64]           [-1, 3, 64, 64]           --
# ========================================================================================================================
# Total params: 4,258,243
# Trainable params: 4,258,243
# Non-trainable params: 0
# Total mult-adds (M): 18.78
# ========================================================================================================================
# Input size (MB): 0.05
# Forward/backward pass size (MB): 0.22
# Params size (MB): 16.24
# Estimated Total Size (MB): 16.51
# ========================================================================================================================

# %% [markdown]
# # Training (Utils)

# %%
# Define the training step
def train(model, data, optimiser, criterion, scheduler=None, device="cpu"):
    """Training step.

    Parameters
    ----------
    model : object
        Convolutional Autoencoder

    data : DataLoader
        Training dataset
    
    criterion : method
        Metric for evaluation

    optimiser : object
        Optimiser

    scheduler : object
        Schedulet object

    device : str
            Device for the calculations

    Returns
    -------
        Training Loss

    """
    model.train()                                                   # Set the model to training mode
    total = 0.                                                      # Initialize the total loss
    for images, label in data:                                      # Iterate over batches of images
        images = images.to(device)
        optimiser.zero_grad()                                       # Set optimiser grad to 0
        recon = model(images)                                       # Generate predicted images
        loss = criterion(recon, images)                             # Calculate the loss
        loss.backward()                                             # Back-propagate
        optimiser.step()                                            # Step the optimiser
        optimiser.zero_grad()                                       # Set optimiser grad to 0
        total += loss.item() * images.size(0) / len(data.dataset)   # Stores the total loss per batch
    
    if scheduler:                                                   # Scheduler for learning rate
        scheduler.step()

    return total

# Define the validation step
def validate(model, data, criterion, device="cpu"):
    """Validation step.

    Parameters
    ----------
    model : object
        Convolutional Autoencoder

    data : DataLoader
        Training dataset

    criterion : method
        Metric for evaluation

    device : str
            Device for the calculations

    Returns
    -------
        Validation Loss

    """
    model.eval()                                                        # Set the model to evaluation mode
    total = 0.                                                          # Initialize the total loss
    with torch.no_grad():                                               # Deactivate the gradient
        for images, label in data:                                      # Iterate over batches of images
            images = images.to(device)
            recon = model(images)                                       # Generate predicted images
            loss = criterion(recon, images)                             # Calculate the loss
            total += loss.item() * images.size(0) / len(data.dataset)   # Stores the total loss per batch
    return total


def plot(model, data, log, n=(2, 6), idxs=None):
    """Plot the training loss and a comparisson between
    original images and its reconstructions.

    Parameters
    ----------
    model : dict
        Dictionary containing a Convolutional Autoencoder model for each metric

    data : DataLoader
        Training dataset

    log : dict
        Dictionary containing the loss and epochs

    n : tuple(int, int)
        Number of images in row and columns to be plotted. The total number
        of images will be given by the multiplication of the values.

    idxs : list-like, default=None
        List of data indices to be used for visualisation. Default is
        None, which generates random sampling

    Returns
    -------
        List of data indices used for visualisation.

    """
    # Get the batch for comparison
    images, labels = next(iter(data))
    
    # Set up plot
    fig = plt.figure(figsize=(27, 16))
    outer = gridspec.GridSpec(1, 2, wspace=0.05, hspace=0,
                              width_ratios=[0.25, 0.75])

    # Loss plot
    metrics = [key.split("_")[-1] for key in log.keys()
                                if "_" in key and "training" in key]
    intermediate_loss = gridspec.GridSpecFromSubplotSpec(len(metrics), 1,
                            subplot_spec=outer[0], 
                            wspace=0.1, hspace=0.2)

    for i, metric in enumerate(metrics):
        ax = plt.Subplot(fig, intermediate_loss[i])
        ax.plot(log["epochs"], log["training_" + metric], 
                label="Training")
        ax.plot(log["epochs"], log["validation_" + metric], 
                label="Validation")
        ax.grid(alpha=.25)
        if i == len(metrics) - 1:
            ax.set_xlabel("Epochs")
        else:
            ax.get_xaxis().set_visible(False)
        ax.title.set_text(metric + " Loss")
        ax.legend()
        fig.add_subplot(ax)

    # Visualise
    intermediate = gridspec.GridSpecFromSubplotSpec(n[0] * (len(metrics) + 1), n[1],
                        subplot_spec=outer[1], 
                        wspace=0.1, hspace=0.1)
    
    if idxs is None:
        idxs = torch.randint(0, images.shape[0], (n[0] * n[1], ))

    for i, idx in enumerate(idxs):
        # Original image
        inner_real = gridspec.GridSpecFromSubplotSpec(1, 2,
                         subplot_spec=intermediate[i], 
                         wspace=0.05, hspace=0)

        # Spatial Domain
        ax = plt.Subplot(fig, inner_real[0])
        ax.imshow(np.transpose(images[idx].squeeze().numpy(), (1, 2, 0)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i < n[1]:
            ax.title.set_text("[Orig.] ")
        fig.add_subplot(ax)

        # Frequency Domain
        gray_image = Grayscale()(images[idx])
        fft = torch.fft.fft2(gray_image)
        fftshifted = torch.fft.fftshift(fft)

        ax = plt.Subplot(fig, inner_real[1])
        ax.imshow(np.transpose(torch.log(1 + torch.abs(fftshifted)).numpy(),
                            (1, 2, 0)),
                cmap="gist_heat")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        fig.add_subplot(ax)

        for k, metric in enumerate(model.keys()):
            # Set to evaluation
            model[metric].eval()

            # Recon Model
            inner_recon = gridspec.GridSpecFromSubplotSpec(1, 2,
                            subplot_spec=intermediate[i + (k + 1) * n[0] * n[1]],
                            wspace=0.05, hspace=0)
            
            # Spatial Domain
            recon = model[metric](images[idx].unsqueeze(0).to(device))
            ax = plt.Subplot(fig, inner_recon[0])
            ax.imshow(np.transpose(recon.cpu().detach().squeeze().numpy(), (1, 2, 0)))
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            if i < n[1]:
                ax.title.set_text("[" + metric + "]")
            fig.add_subplot(ax)

            # Reconstructed Image (Frequency Domain)
            gray_image = Grayscale()(recon)
            fft = torch.fft.fft2(gray_image)
            fftshifted = torch.fft.fftshift(fft)

            ax = plt.Subplot(fig, inner_recon[1])
            ax.imshow(torch.log(1 + torch.abs(fftshifted)).squeeze().cpu().detach().numpy(), 
                      cmap="gist_heat")
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            fig.add_subplot(ax)

    plt.show()
    print("\n")
    return idxs


# Set the model training function
def train_model(model, train_data, valid_data, optimiser, criterion,
                scheduler=None, device="cpu", epochs=100, 
                gradflow=False, save=False, fcmap="seismic", summary_app={},
                plot_frequency=10, plot_idxs=None):
    """Model training.

    Parameters
    ----------
    model : dict
        Dictionary containing a Convolutional Autoencoder model for each metric

    train_data : DataLoader
        Training dataset

    valid_data : DataLoader
        Validation dataset
    
    optimiser : dict
        Dictionary containing an optimiser for each metric

    criterion : dict
        Dictionary containing the metrics

    scheduler : object, default=None
        Schedulet object

    device : str
            Device for the calculations

    epochs : int, default=100
        Training epochs

    plot_frequency: int
        Frequency in which the training results will be plotted
    
     plot_idxs : list-like, default=None
        List of data indices to be used for visualisation. Default is
        None, which generates random sampling

    Returns
    -------
        Dictionary containing trained Convolutional Autoencoder models

    """
    # Set the logging
    log = {"epochs": []}
    log.update({"training_" + metric: [] for metric in model.keys()})
    log.update({"validation_" + metric: [] for metric in model.keys()})

    for epoch in tqdm(range(epochs), leave=True):
        log['epochs'].append(epoch)
        for metric in model.keys():
            # Training step
            train_loss = train(model[metric], train_data,
                            optimiser[metric], criterion[metric],
                            scheduler, device)
            log['training_' + metric].append(train_loss)

            # Validation step
            valid_loss = validate(model[metric], valid_data,
                                criterion[metric], device)
            log['validation_' + metric].append(valid_loss)

        # Visualise the training results at a certain frequency
        if epoch % plot_frequency == 0 or epoch == epochs - 1:
            plot_idxs = plot(model, valid_loader, log, idxs=plot_idxs)

    return model

# %%
def scale2range(x, range=[-1, 1]):
    x_n = (x - x.min()) * (max(range) - min(range)) / (x.max() - x.min()) + min(range)
    return x_n    

def laplacian3D(mesh):
    alpha, beta = -0.3, 1.5
    xx, yy, zz = mesh[:, :, :, 0], mesh[:, :, :, 1], mesh[:, :, :, 2]
    x = torch.sqrt(xx**2 + yy**2 + zz**2) 
    T = 1 - torch.exp(-torch.abs(x) ** alpha) ** beta
    T = scale2range(T, [0.2, 1.])
    return T

# %% [markdown]
# # Training

# %%
# Hyperparameters
channels = 3                                        # Number of channels in the images
features = 16                                       # Number of input features in the encoder
latent_dimension = 128                              # Number of dimensions of the latent space  
img_size = 64                                       # Image size in 1-D
lr = 1e-3                                           # Learning rate
betas = (0.9, 0.999)                                # Beta
epochs = 10                                         # Epochs
plot_frequency = 2                                  # Plot training frequency

# Initialize the model
model = {"MSE": model_instance(device=device, channels=channels,
                               features=features,
                               latent_dimension=latent_dimension,
                               img_dim=img_dim),
         "FFL": model_instance(device=device, channels=channels,
                               features=features,
                               latent_dimension=latent_dimension,
                               img_dim=img_dim),
         "AWL": model_instance(device=device, channels=channels,
                               features=features,
                               latent_dimension=latent_dimension,
                               img_dim=img_dim)}

# Define optimizer
optimiser = {"MSE": torch.optim.Adam(model["MSE"].parameters(), lr=lr, betas=betas),
             "FFL": torch.optim.Adam(model["FFL"].parameters(), lr=lr, betas=betas),
             "AWL": torch.optim.Adam(model["AWL"].parameters(), lr=lr, betas=betas)}

# Define the metrics:
awloss = AWLoss(filter_dim=3,  std=1e-1, 
                epsilon=250., filter_scale=2, 
                reduction="sum", method="fft", 
                store_filters="unorm", 
                penalty_function=laplacian3D)  
ffloss = FFLoss().to(device)
criterion = {"MSE": nn.MSELoss(),
             "FFL": ffloss,
             "AWL": awloss}

# Train
model = train_model(model=model, train_data=train_loader, 
                    valid_data=valid_loader, optimiser=optimiser, 
                    criterion=criterion, device=device, epochs=epochs,
                    plot_frequency=plot_frequency)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# # Analysis (Utils)

# %%
def plot_comparison(model, data, n=5):
    """Compare the original images and its reconstructions.

    Parameters
    ----------
    model : dict
        Dictionary containing a Convolutional Autoencoder model for each metric

    data : DataLoader
        Training dataset

    n : int
        Number of images to be plotted
    """
    # Get the batch for comparison
    images, labels = next(iter(data))
    
    # Plot
    fig = plt.figure(figsize=(27, 12))
    outer = gridspec.GridSpec(len(model.keys()) + 1, n, wspace=0.1, hspace=0.1)
    
    for i, idx in enumerate(torch.randint(0, images.shape[0], (n, ))):
        # Original image
        inner_real = gridspec.GridSpecFromSubplotSpec(1, 2,
                         subplot_spec=outer[i], 
                         wspace=0.1, hspace=0.1)
        
        # Spatial Domain
        ax = plt.Subplot(fig, inner_real[0])
        ax.imshow(np.transpose(images[idx].squeeze().numpy(), (1, 2, 0)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.title.set_text("[Orig.] ")
        fig.add_subplot(ax)

        # Frequency Domain
        gray_image = Grayscale()(images[idx])
        fft = torch.fft.fft2(gray_image)
        fftshifted = torch.fft.fftshift(fft)

        ax = plt.Subplot(fig, inner_real[1])
        ax.imshow(np.transpose(torch.log(1 + torch.abs(fftshifted)).numpy(),
                               (1, 2, 0)),
                  cmap="gist_heat")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        ax.title.set_text("[Orig.] ")
        fig.add_subplot(ax)

        for k, metric in enumerate(model.keys()):
            # Set to evaluation
            model[metric].eval()

            # ReconModel
            inner_recon = gridspec.GridSpecFromSubplotSpec(1, 2,
                            subplot_spec=outer[i + (k + 1) * n],
                            wspace=0.1, hspace=0.1)
            
            # Spatial Domain
            recon =  model[metric](images[idx].unsqueeze(0).to(device))
            ax = plt.Subplot(fig, inner_recon[0])
            ax.imshow(np.transpose(recon.cpu().detach().squeeze().numpy(), (1, 2, 0)))
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            ax.title.set_text("[" + metric + "]")
            fig.add_subplot(ax)

            # Reconstructed Image (Frequency Domain)
            gray_image = Grayscale()(recon)
            fft = torch.fft.fft2(gray_image)
            fftshifted = torch.fft.fftshift(fft)

            ax = plt.Subplot(fig, inner_recon[1])
            ax.imshow(torch.log(1 + torch.abs(fftshifted)).squeeze().cpu().detach().numpy(), 
                      cmap="gist_heat")
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            ax.title.set_text("[" + metric + "]")
            fig.add_subplot(ax)

    plt.show()

# %% [markdown]
# # Analysis

# %%
# Plot the comparisson between the original image and the reconstructed one
plot_comparison(model, valid_loader, n=6)

# %%
def plot(model, data, log, n=(2, 6), idxs=None):
    """Plot the training loss and a comparisson between
    original images and its reconstructions.

    Parameters
    ----------
    model : dict
        Dictionary containing a Convolutional Autoencoder model for each metric

    data : DataLoader
        Training dataset

    log : dict
        Dictionary containing the loss and epochs

    n : tuple(int, int)
        Number of images in row and columns to be plotted. The total number
        of images will be given by the multiplication of the values.

    idxs : list-like, default=None
        List of data indices to be used for visualisation. Default is
        None, which generates random sampling

    Returns
    -------
        List of data indices used for visualisation.

    """
    # Get the batch for comparison
    images, labels = next(iter(data))
    
    # Set up plot
    fig = plt.figure(figsize=(27, 16))
    outer = gridspec.GridSpec(1, 2, wspace=0.05, hspace=0,
                              width_ratios=[0.25, 0.75])

    # Loss plot
    metrics = [key.split("_")[-1] for key in log.keys()
                                if "_" in key and "training" in key]
    intermediate_loss = gridspec.GridSpecFromSubplotSpec(len(metrics), 1,
                            subplot_spec=outer[0], 
                            wspace=0.1, hspace=0.2)

    for i, metric in enumerate(metrics):
        ax = plt.Subplot(fig, intermediate_loss[i])
        ax.plot(log["epochs"], log["training_" + metric], 
                label="Training")
        ax.plot(log["epochs"], log["validation_" + metric], 
                label="Validation")
        ax.grid(alpha=.25)
        if i == len(metrics) - 1:
            ax.set_xlabel("Epochs")
        else:
            ax.get_xaxis().set_visible(False)
        ax.title.set_text(metric + " Loss")
        ax.legend()
        fig.add_subplot(ax)

    # Visualise
    intermediate = gridspec.GridSpecFromSubplotSpec(n[0] * (len(metrics) + 1), n[1],
                        subplot_spec=outer[1], 
                        wspace=0.1, hspace=0.1)
    
    if idxs is None:
        idxs = torch.randint(0, images.shape[0], (n[0] * n[1], ))

    for i, idx in enumerate(idxs):
        # Original image
        inner_real = gridspec.GridSpecFromSubplotSpec(1, 2,
                         subplot_spec=intermediate[i], 
                         wspace=0.05, hspace=0)

        # Spatial Domain
        ax = plt.Subplot(fig, inner_real[0])
        ax.imshow(np.transpose(images[idx].squeeze().numpy(), (1, 2, 0)))
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        if i < n[1]:
            ax.title.set_text("[Orig.] ")
        fig.add_subplot(ax)

        # Frequency Domain
        gray_image = Grayscale()(images[idx])
        fft = torch.fft.fft2(gray_image)
        fftshifted = torch.fft.fftshift(fft)

        ax = plt.Subplot(fig, inner_real[1])
        ax.imshow(np.transpose(torch.log(1 + torch.abs(fftshifted)).numpy(),
                            (1, 2, 0)),
                cmap="gist_heat")
        ax.get_xaxis().set_visible(False)
        ax.get_yaxis().set_visible(False)
        fig.add_subplot(ax)

        for k, metric in enumerate(model.keys()):
            # Set to evaluation
            model[metric].eval()

            # Recon Model
            inner_recon = gridspec.GridSpecFromSubplotSpec(1, 2,
                            subplot_spec=intermediate[i + (k + 1) * n[0] * n[1]],
                            wspace=0.05, hspace=0)
            
            # Spatial Domain
            recon = model[metric](images[idx].unsqueeze(0).to(device))
            ax = plt.Subplot(fig, inner_recon[0])
            ax.imshow(np.transpose(recon.cpu().detach().squeeze().numpy(), (1, 2, 0)))
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            if i < n[1]:
                ax.title.set_text("[" + metric + "]")
            fig.add_subplot(ax)

            # Reconstructed Image (Frequency Domain)
            gray_image = Grayscale()(recon)
            fft = torch.fft.fft2(gray_image)
            fftshifted = torch.fft.fftshift(fft)

            ax = plt.Subplot(fig, inner_recon[1])
            ax.imshow(torch.log(1 + torch.abs(fftshifted)).squeeze().cpu().detach().numpy(), 
                      cmap="gist_heat")
            ax.get_xaxis().set_visible(False)
            ax.get_yaxis().set_visible(False)
            fig.add_subplot(ax)

    plt.show()
    print("\n")
    return idxs

# %%
log = {"epochs": [0, 1, 2]}
log.update({"training_" + metric: [3, 4, 5] for metric in model.keys()})
log.update({"validation_" + metric: [3, 4, 5] for metric in model.keys()})
plot(model, valid_loader, log)
# Out:
# tensor([160, 429, 377, 380, 265, 203,   8, 327, 507, 330, 293, 269])
